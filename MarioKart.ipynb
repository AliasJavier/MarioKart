# %% [markdown]
# # Importamos librerias

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("KartKross.csv")
df = pd.DataFrame(df, columns=['characters','kart','tires','glider','speed','acceleration','weight','handling','traction','turbo','total']
)
print(df)
# Out:
#                  characters        kart         tires         glider  speed  \
# 0         Wario, Dry Bowser    Landship      Off-Road   Plane Glider   4.50
# 1         Wario, Dry Bowser    Landship      Off-Road    Bowser Kite   4.25
# 2         Wario, Dry Bowser    Landship      Off-Road     Wario Wing   4.50
# 3         Wario, Dry Bowser    Landship      Off-Road    Hylian Kite   4.50
# 4         Wario, Dry Bowser    Landship      Off-Road       Parafoil   4.25
# ...                     ...         ...           ...            ...    ...
# 188155  Toad, ShyGuy, Larry  Inkstriker  Crimson Slim  Flower Glider   3.00
# 188156  Toad, ShyGuy, Larry  Inkstriker  Crimson Slim   Super Glider   3.25
# 188157  Toad, ShyGuy, Larry  Inkstriker  Crimson Slim    Waddle Wing   3.25
# 188158  Toad, ShyGuy, Larry  Inkstriker  Crimson Slim  Peach Parasol   3.00
# 188159  Toad, ShyGuy, Larry  Inkstriker  Crimson Slim   Paper Glider   3.00
#
# ...

# %%
display(df.head())
# Out:
#           characters      kart     tires        glider  speed  acceleration  \
# 0  Wario, Dry Bowser  Landship  Off-Road  Plane Glider   4.50          3.25
# 1  Wario, Dry Bowser  Landship  Off-Road   Bowser Kite   4.25          3.50
# 2  Wario, Dry Bowser  Landship  Off-Road    Wario Wing   4.50          3.25
# 3  Wario, Dry Bowser  Landship  Off-Road   Hylian Kite   4.50          3.25
# 4  Wario, Dry Bowser  Landship  Off-Road      Parafoil   4.25          3.50
#
#    weight  handling  traction  turbo  total
# 0    4.25      1.75      4.00   2.75   20.5
# 1    4.00      1.75      4.00   3.00   20.5
# 2    4.25      1.75      4.00   2.75   20.5
# 3    4.00      1.75      4.25   2.75   20.5
# 4    4.00      1.75      4.00   3.00   20.5

# %%
sns.displot(df, x="speed",y="acceleration");

# %%
sns.relplot(x="speed", y="acceleration", data=df);

# %%
sns.displot(x="speed", hue="traction", data=df);
